# %% [markdown]
# # **Aula conceitual inicial de algoritmos com Python**
#
# **Professor Valdemar Lorenzon Junior**
#
# *Colaboração de versões anteriores por Jusane Farina Lara*

# %% [markdown]
# # Lógica
#
# Para entendermos o que é Lógica, precisamos entender o que é um problema. Pode-se dizer que problema é uma proposta duvidosa que pode ter inúmeras soluções ou é uma questão não resolvida que é objeto de discussão, segundo definição de um dicionário.
#
# Para nós, problema é uma questão que foge a uma determinada regra, a qual nos impede de atingirmos com sucesso determinado objetivo. Por isso, temos que descobrir as regras, a ordem das mesmas e resolver o problema usando um procedimento de desenvolvimento.
#
# A lógica de programação é necessária para pessoas que desejam trabalhar com desenvolvimento de sistemas e programas. Ela nos permite definir a seqüência lógica para o desenvolvimento.
#
# **Lógica de programação é a técnica de encadear pensamentos para atingir determinado objetivo.**

# %% [markdown]
# # Seqüência Lógica
#
# Estes pensamentos podem ser descritos como uma seqüência de instruções, que devem ser seguidas para se cumprir uma determinada tarefa.
#
# **Seqüência lógica são os passos executados até atingir um objetivo ou solução de um problema.**

# %% [markdown]
# # Instruções
#
# Numa linguagem comum pode-se dizer que instruções são “um conjunto de regras ou normas definidas para a realização ou emprego de algo”. Pode-se dizer também que são ordens, que quando identificadas, são realizadas. Como exemplo: “Feche os olhos” é uma ordem. O ato de fechar os olhos é a execução desta ordem.
#
# Um conjunto de instruções é determinado para a execução de uma tarefa. Somente este conjunto de instruções em uma ordem seqüencial lógica é capaz de realizar o processo desejado.
#
# **Instruções são um conjunto de regras ou normas definidas para a realização ou emprego de algo. Em informática, é o que indica a um computador uma ação elementar a executar.**

# %%
#Um exemplo de intruções, num pequeno programa Python, desenhado para cada instrução ser em uma linha de código

a = 0 #A declaraçaõ e inicialização de uma variável denominada a
print("Programa exemplo Um.\n\n")
a = input("Informe um valor para uma variável denominada 'a'\n") # input sempre retorna cadeia de caracteres
a = int(a) # Fazendo uso de casting, transformando a string a em um inteiro
a *= 2
print("O dobro do valor informado é", a) #aqui o casting automático - existem n formas de fazer uso do print
# Out:
# Programa exemplo Um.
#
#
# O dobro do valor informado é 20

# %% [markdown]
# # O Algoritmo
#
# **Algoritmo é um conjunto de regras que permite a resolução de um problema ou a execução de um trabalho, através de um número finito de operações.**
#
# As regras que definem um algoritmo podem ser entendidas como instruções que executadas produzem um resultado.
#
# Vamos agora entender como devemos pensar para começarmos a construção de algoritmos. Como exemplo descrevemos abaixo algumas frases que podem ser consideradas como instruções:
#
# *   Escolher uma música a partir de um aplicativo de streaming;
# *   Escovar os dentes;
# *   Chamar por alguém;
# *   Responder uma pergunta;
# *   Atribuir um valor 5 a uma variável.
#
# Este exemplo não demonstra um conjunto de instruções, nem mesmo possui uma seqüência lógica de funcionamento. Para entender uma seqüência de instruções devemos observar os eventos a elas atribuídos. Até mesmo coisas simples podem ser descritas por seqüências lógicas, por exemplo:
#
# Pense no seu objetivo como a resolução de algum "problema". Como chegar a este objetivo, resultado a partir de lógica com instruções dentro de uma sequencia lógica?
#
# Então, num contexto mais adequado: **como somar dois números?**
#
# ![imagem 1.jpg](data:image/jpeg;base64,...)

# %%
#Neste exemplo acima, num programa real, a atribuição e cálculo em expressão seria de forma contrária, veja!

a = b = c = 0 #múltipla atribuição em declaração
a = input("Informe um valor\n")
b = input("\nInforme outro valor\n")
c = int(a+b) # a atribuição é uma variável recebendo "=" um resultado de uma expressão
print("\nO resultado da soma dos dois valores é", c)
# Out:
# O resultado da soma dos dois valores é 50

# %% [markdown]
# # Padrão e desvio de comportamento
#
# Vamos agora a um exemplo mais significativo. Imagine como é o seu despertar. Observe as ações a seguir e tente imaginar a execução das mesmas seqüencialmente:
#
#
# *   Ao toque do alarme, acordar;
# *   Levantar-se;
# *   Ir ao banheiro;
# *   Arrumar-se;
# *   Tomar seu café da manhã;
# *   Escovar os dentes.
#
# Se todos os dias você executa esta mesma ação pela manhã, considerando que possa mudar de roupa a cada dia e possa comer algo diferente no café ou mesmo trocar de creme dental para escovar os dentes, porém se a seqüência das ações não mudar, temos o que chamamos de **padrão de comportamento**.
#
# Como observador você deve descobrir o padrão de comportamento para a resolução de um problema, independente dos fatores externos ou internos que possam existir.
#
# Se em um determinado dia você observar que ao invés de vestir-se antes de tomar o café da manhã, esta ação foi executada depois de escovar os dentes, temos então **um desvio do comportamento**.
#
# Como bom observador você deve ter a capacidade de prever certas ações que desviam o comportamento normal de um procedimento e implementar estas características para concluir o objetivo. Um desvio de comportamento pode dar-se através de uma condição, onde o padrão ainda possa ser executado e algumas vezes, pode-se fugir dele.
#
# Exemplo, em determinado dia você preferiu não tomar o café da manhã!

# %% [markdown]
# # A arte de pensar para criar
#
# Esta é a tarefa do construtor de algoritmos, do programador, ou mesmo até um analista de sistemas: Observar, levantar dados sobre ações e informações a respeito de uma execução para criação e abstração desta em modo computacional.
#
# Pensar antes de fazer. Fazer e observar. Testar as ações escritas.  Tornar possível o incremento e o decremento de ações no processo da solução do problema.
#
# Com isso temos um poderoso conceito de algoritmo:
#
# **Um texto estático, capaz de cobrir toda uma classe de acontecimentos, no mesmo nível de detalhe de relato de um observador.**
#
# Os programas de computador nada mais são do que algoritmos escritos em uma linguagem de computador (Pascal, C, Cobol, Fortran, Basic, JAVA, Python, Ruby, entre outras) e que são executados por uma máquina, no caso um computador.

# %% [markdown]
# # Os problemas a serem resolvidos durante o aprendizado da lógica e algoritmos
#
# Algumas situações serão enfrentadas ao longo do caminho e precisam ser observadas, por isso, já vamos classificar e entender estes tópicos:
#
# 1. Tentativa e erro;
# 2. Erros de sintaxe e busca de solução;
# 3. Copiar (Do outro, de alguém ou da internet ou bibliografias, etc.);
# 4. A falta de ideia, criatividade e a estafa mental.
# 5. O Erro lógico do programa que não tem erro sintático;
# 6. O algoritmo/programa que execta sem fim;
# 7. O algoritmo/programa que falha em alguns casos não pensados;
#
# Então, como proceder?
#
# 1. Pensar antes de fazer, esboçar;
# 2. Utilizar comentários dentro do seu algortimo/programa;
# 3. Ser objetivo, mas dar clareza de leitura/entendimento de seu código;
# 4. Cuidado com códigos de **processamento** complexos (demais);
# 5. Fazer o que se pede, mas incrementar nas **entradas** e **saídas**;
# 6. Testar, mas testar!
# 7. Refazer, se pode melhorar!

# %%
#programa de apresentação de alguns erros e novidades
a = 0
a = int(input("Informe um valor"))
print(a)
# Out:
# 10

# %% [markdown]
# # Fases dos Algoritmos – Entrada, Processamento e Saída
#
# Definimos que algoritmos possuem uma ordem lógica de instruções para execução de uma tarefa. Para montar um algoritmo precisamos dividir o problema apresentado em três fases fundamentais, onde temos:
#
# **Entrada**: São os dados de entrada do algoritmo, os valores iniciais que podem ser descritos ou solicitados;
#
# **Processamento**: São os procedimentos (instruções) utilizados para se alcançar o resultado final (objetivo do algoritmo);
#
# **Saída**: São os dados processados que podem ser exibidos, retornados ou impressos. A saída pode ser entendida como algo apresentado no vídeo do computador ou na impressora.
#
#
# > Exemplo de pseudo algoritmo
#
# Vamos imaginar o seguinte problema: Calcular a média final dos alunos de uma   disciplina, sabendo-se como o cálculo é realizado através de uma média aritmética de duas notas.
#
# Para montarmos o algoritmo proposto, responda as seguintes perguntas:
#
# •	Quais são os valores de entrada?
# •	Como você vai nomear os valores que deseja receber?
# •	Qual será o procedimento a ser executado sobre estes valores?
# •	Qual é o valor de saída, se fossemos nomeá-lo?
#
# **Pseudo-Algoritmo**: Escreva o algoritmo como frases naturais a serem executadas em tarefas uma após a outra a fim de chegar no resultado de indicação do resultado da média final do aluno. Dê nome as valores que você quer de entrada, resultado de cálculos e valores a serem apresentados como saída.

# %% [markdown]
# # Teste de Mesa
#
# Após o desenvolvimento de um algoritmo ele deverá ser sempre testado. Este teste é conhecido como teste de mesa, que significa, seguir as instruções do algoritmo de maneira precisa para verificar se o procedimento utilizado para a resolução do problema está correto ou não.
#
# O teste deve ser realizado com anotações como a criação de uma tabela que sugere o mapeamento de uma memória computacional com o espaço para todos as variáveis e valores, tanto de entrada como de saída, que deve ser preenchida conforme a execução do algoritmo numa forma seqüencial.
#
# O Teste de mesa é fundamental para o aprendizado dos algoritmos, não somente para verificar se o algoritmo faz o que se pede, mas para entender a seqüência lógica das operações. Acostume-se a realizar testes de mesa, ele facilita o aprendizado.
#
# Um exemplo mais próximo do teste de mesa no que tange ao assunto algoritmos podem ser observado no exercício a seguir:
#
# Um elemento chamado A possui um valor inicial inteiro 10. Este elemento deve ser multiplicado por outro elemento, denominado B. O valor de B foi solicitado para o usuário e deu-se entrada no valor 2. Após o processamento da multiplicação ocorrer, o valor desta multiplicação foi dividido por 2 e a parte inteira desta divisão foi colocada em B.
#
# *Atividade com o professor em explanação em sala.*

# %% [markdown]
# # Lema
#
# Quanto mais se estuda, mais se conhece.
#
# Quanto mais se conhece, mais se sabe.
#
# Quanto mais se sabe, mais se ensina.
#
# Quanto mais se ensina, mais se aprende.
#
# Quanto mais se copia, menos se conhece.
